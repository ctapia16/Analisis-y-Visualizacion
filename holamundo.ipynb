# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
print("--Captura tu nombre--")
myName = input("¿Cuál es tu nombre? ")
print("Hola " + myName + ", es un gusto saludarte")
# Out:
# --Captura tu nombre--
# Hola Carlos, es un gusto saludarte
